# %%
import re
import pandas as pd
import numpy as np
from plotnine import *
from pandas import DataFrame, read_csv
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Reading the Airline CSV files
def readData():
    colnames = ['airline_name','overall_score','review_title','reviewer_country','review_date','aircraft_model','travel_type','seat_type','route','date_flown','seat_comfort_rating','service_rating','food_rating','entertainment_rating','groundservice_rating','wifi_rating','value_rating','recommended']
    Afrance = pd.read_csv(f"{url}/Airlines_Data/air-france.csv",header = None,names = colnames)
    Ana = pd.read_csv(f"{url}/Airlines_Data/ana-all-nippon-airways.csv",header = None,names = colnames)
    Emirates = pd.read_csv(f"{url}/Airlines_Data/emirates.csv",header = None,names = colnames)
    Japan = pd.read_csv(f"{url}/Airlines_Data/japan-airlines.csv",header = None,names = colnames)
    Korean = pd.read_csv(f"{url}/Airlines_Data/korean-air.csv",header = None,names = colnames)
    Qantas = pd.read_csv(f"{url}/Airlines_Data/qantas-airways.csv",header = None,names = colnames)
    Qatar = pd.read_csv(f"{url}/Airlines_Data/qatar-airways.csv",header = None,names = colnames)
    Singapore = pd.read_csv(f"{url}/Airlines_Data/singapore-airlines.csv",header = None,names = colnames)
    Swiss = pd.read_csv(f"{url}/Airlines_Data/swiss-international-air-lines.csv",header = None,names = colnames)
    Turkish = pd.read_csv(f"{url}/Airlines_Data/turkish-airlines.csv",header = None,names = colnames)
    df = pd.concat([Afrance,Afrance,Ana,Emirates,Japan,Korean,Qantas,Qatar,Singapore,Swiss,Turkish])
    return df

# %%
colnames = ['airline_name','overall_score','review_title','reviewer_country','review_date','aircraft_model','travel_type','seat_type','route','date_flown','seat_comfort_rating','service_rating','food_rating','entertainment_rating','groundservice_rating','wifi_rating','value_rating','recommended']
Afrance = pd.read_csv("/Users/shreyajaiswal/Desktop/Shreya/Semester_one/DMDD/Assignment 3 /Web_Scrapping_Data/Airlines_Data/air-france.csv",header = None,names = colnames)
display(Afrance)
# Out:
#     airline_name  overall_score  \
# 0     air france              4
# 1     air france             10
# 2     air france              1
# 3     air france              2
# 4     air france              1
# ..           ...            ...
# 995   air france              3
# 996   air france              6
# 997   air france              3
# 998   air france              7
# 999   air france              1
#
#                                       review_title   reviewer_country  \
# 0        "return flight was changed so many times"   (New Caledonia)
# 1                             "Plane was spotless"   (New Caledonia)
# 2                 "got nothing but the run around"   (New Caledonia)
# 3                            "would not recommend"   (New Caledonia)
# 4    "didn’t bother to put my bag on the aircraft"   (New Caledonia)
# ..                                             ...                ...
# 995                     Air France customer review       (Australia)
# 996                     Air France customer review       (Australia)
# 997                     Air France customer review       (Australia)
# 998                     Air France customer review       (Australia)
# 999                     Air France customer review       (Australia)
#
#          review_date aircraft_model     travel_type        seat_type  \
# 0       9th May 2022            NaN  Couple Leisure    Economy Class
# 1       5th May 2022            NaN    Solo Leisure    Economy Class
# 2    19th April 2022            NaN    Solo Leisure    Economy Class
# 3    15th April 2022            NaN  Family Leisure    Economy Class
# 4     6th April 2022           A319        Business    Economy Class
# ..               ...            ...             ...              ...
# 995   13th July 2014            NaN             NaN    Economy Class
# 996   11th July 2014            NaN             NaN    Economy Class
# 997   11th July 2014            NaN             NaN    Economy Class
# 998    6th July 2014            NaN             NaN   Business Class
# 999   30th June 2014            NaN             NaN  Premium Economy
#
#                              route      date_flown  seat_comfort_rating  \
# 0               Paris to Amsterdam        May 2022                    1
# 1                    Paris to Lyon        May 2022                    5
# 2                              NaN  September 2021                    0
# 3    Tel Aviv to Toronto via Paris      April 2022                    3
# 4               Paris to Newcastle      April 2022                    1
# ..                             ...             ...                  ...
# 995                            NaN             NaN                    2
# 996                            NaN             NaN                    2
# 997                            NaN             NaN                    3
# 998                            NaN             NaN                    4
# 999                            NaN             NaN                    1
#
#      service_rating  food_rating  entertainment_rating  groundservice_rating  \
# 0                 3            1                     0                     2
# 1                 5            5                     0                     5
# 2                 0            0                     0                     0
# 3                 1            2                     3                     1
# 4                 1            1                     0                     1
# ..              ...          ...                   ...                   ...
# 995               2            4                     1                     0
# 996               3            3                     3                     0
# 997               2            1                     1                     0
# 998               4            4                     4                     0
# 999               1            1                     1                     0
#
#      wifi_rating  value_rating recommended
# 0              0             1         NaN
# 1              0             5         yes
# 2              0             1         NaN
# 3              4             1         NaN
# 4              1             1         NaN
# ..           ...           ...         ...
# 995            0             3         NaN
# 996            0             3         yes
# 997            0             3         NaN
# 998            0             4         yes
# 999            0             1         NaN
#
# [1000 rows x 18 columns]

# %%
#READING THE CONCATENATED CSV VALUES

df_airline_reviews = readData()
display(df_airline_reviews)
#print(len(df_airline_reviews))
# Out:
#          airline_name  overall_score  \
# 0          air france            4.0
# 1          air france           10.0
# 2          air france            1.0
# 3          air france            2.0
# 4          air france            1.0
# ..                ...            ...
# 995  turkish airlines            1.0
# 996  turkish airlines            3.0
# 997  turkish airlines            1.0
# 998  turkish airlines            1.0
# 999  turkish airlines            3.0
#
#                                       review_title   reviewer_country  \
# 0        "return flight was changed so many times"   (New Caledonia)
# 1                             "Plane was spotless"   (New Caledonia)
# 2                 "got nothing but the run around"   (New Caledonia)
# 3                            "would not recommend"   (New Caledonia)
# 4    "didn’t bother to put my bag on the aircraft"   (New Caledonia)
# ..                                             ...                ...
# 995                     "most uncomfortable seats"   (United States)
# 996                      "never walking the cabin"   (United States)
# 997            "at the back of the plane chatting"   (United States)
# 998                       "Well, money, obviously"   (United States)
# 999                 "incompetent customer service"   (United States)
#
#          review_date    aircraft_model     travel_type        seat_type  \
# 0       9th May 2022               NaN  Couple Leisure    Economy Class
# 1       5th May 2022               NaN    Solo Leisure    Economy Class
# 2    19th April 2022               NaN    Solo Leisure    Economy Class
# 3    15th April 2022               NaN  Family Leisure    Economy Class
# 4     6th April 2022              A319        Business    Economy Class
# ..               ...               ...             ...              ...
# 995   16th July 2018               NaN  Couple Leisure   Business Class
# 996   16th July 2018        Boeing 777    Solo Leisure   Business Class
# 997   15th July 2018  Boeing 777-300ER    Solo Leisure    Economy Class
# 998   15th July 2018               NaN  Couple Leisure  Premium Economy
# 999   13th July 2018               NaN  Couple Leisure    Economy Class
#
#                                      route      date_flown  \
# 0                       Paris to Amsterdam        May 2022
# 1                            Paris to Lyon        May 2022
# 2                                      NaN  September 2021
# 3            Tel Aviv to Toronto via Paris      April 2022
# 4                       Paris to Newcastle      April 2022
# ..                                     ...             ...
# 995       Mumbai to Helsinki via Instanbul       July 2018
# 996                     Manila to Istanbul       July 2018
# 997        Tel Aviv to Manila via Istanbul       June 2018
# 998      Kayseri to Bucharest via Istanbul       July 2018
# 999  Los Angeles to Bucharest via Istanbul       July 2018
#
#      seat_comfort_rating  service_rating  food_rating  entertainment_rating  \
# 0                      1               3            1                     0
# 1                      5               5            5                     0
# 2                      0               0            0                     0
# 3                      3               1            2                     3
# 4                      1               1            1                     0
# ..                   ...             ...          ...                   ...
# 995                    1               2            2                     2
# 996                    3               1            1                     2
# 997                    3               1            2                     4
# 998                    1               1            1                     1
# 999                    4               4            5                     4
#
#      groundservice_rating  wifi_rating  value_rating recommended
# 0                       2            0             1         NaN
# 1                       5            0             5         yes
# 2                       0            0             1         NaN
# 3                       1            4             1         NaN
# 4                       1            1             1         NaN
# ..                    ...          ...           ...         ...
# 995                     1            0             1         NaN
# 996                     2            1             1         NaN
# 997                     3            0             1         NaN
# 998                     1            1             1         NaN
# 999                     1            4             1         NaN
#
# [9431 rows x 18 columns]

# %%
#REMOVING THE DUPLICATE VALUES

df_airline_reviews = df_airline_reviews.drop_duplicates(keep='first')
display(df_airline_reviews)
print(len(df_airline_reviews))
# Out:
#          airline_name  overall_score  \
# 0          air france            4.0
# 1          air france           10.0
# 2          air france            1.0
# 3          air france            2.0
# 4          air france            1.0
# ..                ...            ...
# 995  turkish airlines            1.0
# 996  turkish airlines            3.0
# 997  turkish airlines            1.0
# 998  turkish airlines            1.0
# 999  turkish airlines            3.0
#
#                                       review_title   reviewer_country  \
# 0        "return flight was changed so many times"   (New Caledonia)
# 1                             "Plane was spotless"   (New Caledonia)
# 2                 "got nothing but the run around"   (New Caledonia)
# 3                            "would not recommend"   (New Caledonia)
# 4    "didn’t bother to put my bag on the aircraft"   (New Caledonia)
# ..                                             ...                ...
# 995                     "most uncomfortable seats"   (United States)
# 996                      "never walking the cabin"   (United States)
# 997            "at the back of the plane chatting"   (United States)
# 998                       "Well, money, obviously"   (United States)
# 999                 "incompetent customer service"   (United States)
#
#          review_date    aircraft_model     travel_type        seat_type  \
# 0       9th May 2022               NaN  Couple Leisure    Economy Class
# 1       5th May 2022               NaN    Solo Leisure    Economy Class
# 2    19th April 2022               NaN    Solo Leisure    Economy Class
# 3    15th April 2022               NaN  Family Leisure    Economy Class
# 4     6th April 2022              A319        Business    Economy Class
# ..               ...               ...             ...              ...
# 995   16th July 2018               NaN  Couple Leisure   Business Class
# 996   16th July 2018        Boeing 777    Solo Leisure   Business Class
# 997   15th July 2018  Boeing 777-300ER    Solo Leisure    Economy Class
# 998   15th July 2018               NaN  Couple Leisure  Premium Economy
# 999   13th July 2018               NaN  Couple Leisure    Economy Class
#
#                                      route      date_flown  \
# 0                       Paris to Amsterdam        May 2022
# 1                            Paris to Lyon        May 2022
# 2                                      NaN  September 2021
# 3            Tel Aviv to Toronto via Paris      April 2022
# 4                       Paris to Newcastle      April 2022
# ..                                     ...             ...
# 995       Mumbai to Helsinki via Instanbul       July 2018
# 996                     Manila to Istanbul       July 2018
# 997        Tel Aviv to Manila via Istanbul       June 2018
# 998      Kayseri to Bucharest via Istanbul       July 2018
# 999  Los Angeles to Bucharest via Istanbul       July 2018
#
#      seat_comfort_rating  service_rating  food_rating  entertainment_rating  \
# 0                      1               3            1                     0
# 1                      5               5            5                     0
# 2                      0               0            0                     0
# 3                      3               1            2                     3
# 4                      1               1            1                     0
# ..                   ...             ...          ...                   ...
# 995                    1               2            2                     2
# 996                    3               1            1                     2
# 997                    3               1            2                     4
# 998                    1               1            1                     1
# 999                    4               4            5                     4
#
#      groundservice_rating  wifi_rating  value_rating recommended
# 0                       2            0             1         NaN
# 1                       5            0             5         yes
# 2                       0            0             1         NaN
# 3                       1            4             1         NaN
# 4                       1            1             1         NaN
# ..                    ...          ...           ...         ...
# 995                     1            0             1         NaN
# 996                     2            1             1         NaN
# 997                     3            0             1         NaN
# 998                     1            1             1         NaN
# 999                     1            4             1         NaN
#
# [8319 rows x 18 columns]
# 8319

# %%
#DROPPING THE FIRST ROW AS IT WAS REDUNDANT HEADER

df_airline_reviews = df_airline_reviews.drop([0])
display(df_airline_reviews)
# Out:
#          airline_name  overall_score  \
# 1          air france           10.0
# 2          air france            1.0
# 3          air france            2.0
# 4          air france            1.0
# 5          air france            7.0
# ..                ...            ...
# 995  turkish airlines            1.0
# 996  turkish airlines            3.0
# 997  turkish airlines            1.0
# 998  turkish airlines            1.0
# 999  turkish airlines            3.0
#
#                                       review_title   reviewer_country  \
# 1                             "Plane was spotless"   (New Caledonia)
# 2                 "got nothing but the run around"   (New Caledonia)
# 3                            "would not recommend"   (New Caledonia)
# 4    "didn’t bother to put my bag on the aircraft"   (New Caledonia)
# 5                 "nothing by way of compensation"   (New Caledonia)
# ..                                             ...                ...
# 995                     "most uncomfortable seats"   (United States)
# 996                      "never walking the cabin"   (United States)
# 997            "at the back of the plane chatting"   (United States)
# 998                       "Well, money, obviously"   (United States)
# 999                 "incompetent customer service"   (United States)
#
#          review_date            aircraft_model     travel_type  \
# 1       5th May 2022                       NaN    Solo Leisure
# 2    19th April 2022                       NaN    Solo Leisure
# 3    15th April 2022                       NaN  Family Leisure
# 4     6th April 2022                      A319        Business
# 5     5th April 2022  Boeing 777-200 / 777-300        Business
# ..               ...                       ...             ...
# 995   16th July 2018                       NaN  Couple Leisure
# 996   16th July 2018                Boeing 777    Solo Leisure
# 997   15th July 2018          Boeing 777-300ER    Solo Leisure
# 998   15th July 2018                       NaN  Couple Leisure
# 999   13th July 2018                       NaN  Couple Leisure
#
#            seat_type                                  route      date_flown  \
# 1      Economy Class                          Paris to Lyon        May 2022
# 2      Economy Class                                    NaN  September 2021
# 3      Economy Class          Tel Aviv to Toronto via Paris      April 2022
# 4      Economy Class                     Paris to Newcastle      April 2022
# 5     Business Class        Conakry to Washington via Paris   December 2021
# ..               ...                                    ...             ...
# 995   Business Class       Mumbai to Helsinki via Instanbul       July 2018
# 996   Business Class                     Manila to Istanbul       July 2018
# 997    Economy Class        Tel Aviv to Manila via Istanbul       June 2018
# 998  Premium Economy      Kayseri to Bucharest via Istanbul       July 2018
# 999    Economy Class  Los Angeles to Bucharest via Istanbul       July 2018
#
#      seat_comfort_rating  service_rating  food_rating  entertainment_rating  \
# 1                      5               5            5                     0
# 2                      0               0            0                     0
# 3                      3               1            2                     3
# 4                      1               1            1                     0
# 5                      4               4            4                     4
# ..                   ...             ...          ...                   ...
# 995                    1               2            2                     2
# 996                    3               1            1                     2
# 997                    3               1            2                     4
# 998                    1               1            1                     1
# 999                    4               4            5                     4
#
#      groundservice_rating  wifi_rating  value_rating recommended
# 1                       5            0             5         yes
# 2                       0            0             1         NaN
# 3                       1            4             1         NaN
# 4                       1            1             1         NaN
# 5                       2            4             3         yes
# ..                    ...          ...           ...         ...
# 995                     1            0             1         NaN
# 996                     2            1             1         NaN
# 997                     3            0             1         NaN
# 998                     1            1             1         NaN
# 999                     1            4             1         NaN
#
# [8309 rows x 18 columns]

# %%
#REGEX FUNCTION DEFINED TO REMOVE SPECIAL CHARACTERS

def stripChar(x):
    try:
        return re.sub("[()\"]","",x)
    except:
        return np.nan

# %%
print(df_airline_reviews.columns)

#df_top10.ReviewrCountry = df_top10.ReviewrCountry.apply(lambda x: stripChar(x))
# Out:
# Index(['airline_name', 'overall_score', 'review_title', 'reviewer_country',
#        'review_date', 'aircraft_model', 'travel_type', 'seat_type', 'route',
#        'date_flown', 'seat_comfort_rating', 'service_rating', 'food_rating',
#        'entertainment_rating', 'groundservice_rating', 'wifi_rating',
#        'value_rating', 'recommended'],
#       dtype='object')

# %%
#REMOVING THE SPECIAL CHARS FROM ALL THE COLUMNS

df_airline_reviews.review_title = df_airline_reviews.review_title.apply(lambda x: stripChar(x))
df_airline_reviews.reviewer_country = df_airline_reviews.reviewer_country.apply(lambda x: stripChar(x))
display(df_airline_reviews)
# Out:
#          airline_name  overall_score  \
# 1          air france           10.0
# 2          air france            1.0
# 3          air france            2.0
# 4          air france            1.0
# 5          air france            7.0
# ..                ...            ...
# 995  turkish airlines            1.0
# 996  turkish airlines            3.0
# 997  turkish airlines            1.0
# 998  turkish airlines            1.0
# 999  turkish airlines            3.0
#
#                                     review_title reviewer_country  \
# 1                             Plane was spotless   New Caledonia
# 2                 got nothing but the run around   New Caledonia
# 3                            would not recommend   New Caledonia
# 4    didn’t bother to put my bag on the aircraft   New Caledonia
# 5                 nothing by way of compensation   New Caledonia
# ..                                           ...              ...
# 995                     most uncomfortable seats   United States
# 996                      never walking the cabin   United States
# 997            at the back of the plane chatting   United States
# 998                       Well, money, obviously   United States
# 999                 incompetent customer service   United States
#
#          review_date            aircraft_model     travel_type  \
# 1       5th May 2022                       NaN    Solo Leisure
# 2    19th April 2022                       NaN    Solo Leisure
# 3    15th April 2022                       NaN  Family Leisure
# 4     6th April 2022                      A319        Business
# 5     5th April 2022  Boeing 777-200 / 777-300        Business
# ..               ...                       ...             ...
# 995   16th July 2018                       NaN  Couple Leisure
# 996   16th July 2018                Boeing 777    Solo Leisure
# 997   15th July 2018          Boeing 777-300ER    Solo Leisure
# 998   15th July 2018                       NaN  Couple Leisure
# 999   13th July 2018                       NaN  Couple Leisure
#
#            seat_type                                  route      date_flown  \
# 1      Economy Class                          Paris to Lyon        May 2022
# 2      Economy Class                                    NaN  September 2021
# 3      Economy Class          Tel Aviv to Toronto via Paris      April 2022
# 4      Economy Class                     Paris to Newcastle      April 2022
# 5     Business Class        Conakry to Washington via Paris   December 2021
# ..               ...                                    ...             ...
# 995   Business Class       Mumbai to Helsinki via Instanbul       July 2018
# 996   Business Class                     Manila to Istanbul       July 2018
# 997    Economy Class        Tel Aviv to Manila via Istanbul       June 2018
# 998  Premium Economy      Kayseri to Bucharest via Istanbul       July 2018
# 999    Economy Class  Los Angeles to Bucharest via Istanbul       July 2018
#
#      seat_comfort_rating  service_rating  food_rating  entertainment_rating  \
# 1                      5               5            5                     0
# 2                      0               0            0                     0
# 3                      3               1            2                     3
# 4                      1               1            1                     0
# 5                      4               4            4                     4
# ..                   ...             ...          ...                   ...
# 995                    1               2            2                     2
# 996                    3               1            1                     2
# 997                    3               1            2                     4
# 998                    1               1            1                     1
# 999                    4               4            5                     4
#
#      groundservice_rating  wifi_rating  value_rating recommended
# 1                       5            0             5         yes
# 2                       0            0             1         NaN
# 3                       1            4             1         NaN
# 4                       1            1             1         NaN
# 5                       2            4             3         yes
# ..                    ...          ...           ...         ...
# 995                     1            0             1         NaN
# 996                     2            1             1         NaN
# 997                     3            0             1         NaN
# 998                     1            1             1         NaN
# 999                     1            4             1         NaN
#
# [8309 rows x 18 columns]

# %%
#REMOVING THE ROWS WITH NA OR Nan

df_airline_reviews.recommended = df_airline_reviews.recommended.fillna(value = 0)
display(df_airline_reviews)
# Out:
#          airline_name  overall_score  \
# 1          air france           10.0
# 2          air france            1.0
# 3          air france            2.0
# 4          air france            1.0
# 5          air france            7.0
# ..                ...            ...
# 995  turkish airlines            1.0
# 996  turkish airlines            3.0
# 997  turkish airlines            1.0
# 998  turkish airlines            1.0
# 999  turkish airlines            3.0
#
#                                     review_title reviewer_country  \
# 1                             Plane was spotless   New Caledonia
# 2                 got nothing but the run around   New Caledonia
# 3                            would not recommend   New Caledonia
# 4    didn’t bother to put my bag on the aircraft   New Caledonia
# 5                 nothing by way of compensation   New Caledonia
# ..                                           ...              ...
# 995                     most uncomfortable seats   United States
# 996                      never walking the cabin   United States
# 997            at the back of the plane chatting   United States
# 998                       Well, money, obviously   United States
# 999                 incompetent customer service   United States
#
#          review_date            aircraft_model     travel_type  \
# 1       5th May 2022                       NaN    Solo Leisure
# 2    19th April 2022                       NaN    Solo Leisure
# 3    15th April 2022                       NaN  Family Leisure
# 4     6th April 2022                      A319        Business
# 5     5th April 2022  Boeing 777-200 / 777-300        Business
# ..               ...                       ...             ...
# 995   16th July 2018                       NaN  Couple Leisure
# 996   16th July 2018                Boeing 777    Solo Leisure
# 997   15th July 2018          Boeing 777-300ER    Solo Leisure
# 998   15th July 2018                       NaN  Couple Leisure
# 999   13th July 2018                       NaN  Couple Leisure
#
#            seat_type                                  route      date_flown  \
# 1      Economy Class                          Paris to Lyon        May 2022
# 2      Economy Class                                    NaN  September 2021
# 3      Economy Class          Tel Aviv to Toronto via Paris      April 2022
# 4      Economy Class                     Paris to Newcastle      April 2022
# 5     Business Class        Conakry to Washington via Paris   December 2021
# ..               ...                                    ...             ...
# 995   Business Class       Mumbai to Helsinki via Instanbul       July 2018
# 996   Business Class                     Manila to Istanbul       July 2018
# 997    Economy Class        Tel Aviv to Manila via Istanbul       June 2018
# 998  Premium Economy      Kayseri to Bucharest via Istanbul       July 2018
# 999    Economy Class  Los Angeles to Bucharest via Istanbul       July 2018
#
#      seat_comfort_rating  service_rating  food_rating  entertainment_rating  \
# 1                      5               5            5                     0
# 2                      0               0            0                     0
# 3                      3               1            2                     3
# 4                      1               1            1                     0
# 5                      4               4            4                     4
# ..                   ...             ...          ...                   ...
# 995                    1               2            2                     2
# 996                    3               1            1                     2
# 997                    3               1            2                     4
# 998                    1               1            1                     1
# 999                    4               4            5                     4
#
#      groundservice_rating  wifi_rating  value_rating recommended
# 1                       5            0             5         yes
# 2                       0            0             1           0
# 3                       1            4             1           0
# 4                       1            1             1           0
# 5                       2            4             3         yes
# ..                    ...          ...           ...         ...
# 995                     1            0             1           0
# 996                     2            1             1           0
# 997                     3            0             1           0
# 998                     1            1             1           0
# 999                     1            4             1           0
#
# [8309 rows x 18 columns]

# %%
#EQUATING YES to 1

df_airline_reviews.recommended = df_airline_reviews.recommended.eq('yes').mul(1)
display(df_airline_reviews)
# Out:
#          airline_name  overall_score  \
# 1          air france           10.0
# 2          air france            1.0
# 3          air france            2.0
# 4          air france            1.0
# 5          air france            7.0
# ..                ...            ...
# 995  turkish airlines            1.0
# 996  turkish airlines            3.0
# 997  turkish airlines            1.0
# 998  turkish airlines            1.0
# 999  turkish airlines            3.0
#
#                                     review_title reviewer_country  \
# 1                             Plane was spotless   New Caledonia
# 2                 got nothing but the run around   New Caledonia
# 3                            would not recommend   New Caledonia
# 4    didn’t bother to put my bag on the aircraft   New Caledonia
# 5                 nothing by way of compensation   New Caledonia
# ..                                           ...              ...
# 995                     most uncomfortable seats   United States
# 996                      never walking the cabin   United States
# 997            at the back of the plane chatting   United States
# 998                       Well, money, obviously   United States
# 999                 incompetent customer service   United States
#
#          review_date            aircraft_model     travel_type  \
# 1       5th May 2022                       NaN    Solo Leisure
# 2    19th April 2022                       NaN    Solo Leisure
# 3    15th April 2022                       NaN  Family Leisure
# 4     6th April 2022                      A319        Business
# 5     5th April 2022  Boeing 777-200 / 777-300        Business
# ..               ...                       ...             ...
# 995   16th July 2018                       NaN  Couple Leisure
# 996   16th July 2018                Boeing 777    Solo Leisure
# 997   15th July 2018          Boeing 777-300ER    Solo Leisure
# 998   15th July 2018                       NaN  Couple Leisure
# 999   13th July 2018                       NaN  Couple Leisure
#
#            seat_type                                  route      date_flown  \
# 1      Economy Class                          Paris to Lyon        May 2022
# 2      Economy Class                                    NaN  September 2021
# 3      Economy Class          Tel Aviv to Toronto via Paris      April 2022
# 4      Economy Class                     Paris to Newcastle      April 2022
# 5     Business Class        Conakry to Washington via Paris   December 2021
# ..               ...                                    ...             ...
# 995   Business Class       Mumbai to Helsinki via Instanbul       July 2018
# 996   Business Class                     Manila to Istanbul       July 2018
# 997    Economy Class        Tel Aviv to Manila via Istanbul       June 2018
# 998  Premium Economy      Kayseri to Bucharest via Istanbul       July 2018
# 999    Economy Class  Los Angeles to Bucharest via Istanbul       July 2018
#
#      seat_comfort_rating  service_rating  food_rating  entertainment_rating  \
# 1                      5               5            5                     0
# 2                      0               0            0                     0
# 3                      3               1            2                     3
# 4                      1               1            1                     0
# 5                      4               4            4                     4
# ..                   ...             ...          ...                   ...
# 995                    1               2            2                     2
# 996                    3               1            1                     2
# 997                    3               1            2                     4
# 998                    1               1            1                     1
# 999                    4               4            5                     4
#
#      groundservice_rating  wifi_rating  value_rating  recommended
# 1                       5            0             5            1
# 2                       0            0             1            0
# 3                       1            4             1            0
# 4                       1            1             1            0
# 5                       2            4             3            1
# ..                    ...          ...           ...          ...
# 995                     1            0             1            0
# 996                     2            1             1            0
# 997                     3            0             1            0
# 998                     1            1             1            0
# 999                     1            4             1            0
#
# [8309 rows x 18 columns]

# %%
df_airline_reviews.dtypes
# Out:
# airline_name             object
# overall_score           float64
# review_title             object
# reviewer_country         object
# review_date              object
# aircraft_model           object
# travel_type              object
# seat_type                object
# route                    object
# date_flown               object
# seat_comfort_rating       int64
# service_rating            int64
# food_rating               int64
# entertainment_rating      int64
# groundservice_rating      int64
# wifi_rating               int64
# value_rating              int64
# recommended               int64
# dtype: object

# %%
#CLEANING DATETIME FORMATS

df_airline_reviews['review_date'] = pd.to_datetime(df_airline_reviews['review_date'])
df_airline_reviews['year'] = df_airline_reviews['review_date'].dt.year
df_airline_reviews['month'] = df_airline_reviews['review_date'].dt.month
df_airline_reviews.drop(['date_flown'], axis=1)

#df_airline_reviews.to_csv(f'/Users/shreyajaiswal/Desktop/Shreya/Semester_one/DMDD/Assignment 3 /Web_Scrapping_Data/Airlines_Data/reviews.csv', mode='a', header=True, index=False)
# Out:
#          airline_name  overall_score  \
# 1          air france           10.0
# 2          air france            1.0
# 3          air france            2.0
# 4          air france            1.0
# 5          air france            7.0
# ..                ...            ...
# 995  turkish airlines            1.0
# 996  turkish airlines            3.0
# 997  turkish airlines            1.0
# 998  turkish airlines            1.0
# 999  turkish airlines            3.0
#
#                                     review_title reviewer_country review_date  \
# 1                             Plane was spotless   New Caledonia   2022-05-05
# 2                 got nothing but the run around   New Caledonia   2022-04-19
# 3                            would not recommend   New Caledonia   2022-04-15
# 4    didn’t bother to put my bag on the aircraft   New Caledonia   2022-04-06
# 5                 nothing by way of compensation   New Caledonia   2022-04-05
# ..                                           ...              ...         ...
# 995                     most uncomfortable seats   United States   2018-07-16
# 996                      never walking the cabin   United States   2018-07-16
# 997            at the back of the plane chatting   United States   2018-07-15
# 998                       Well, money, obviously   United States   2018-07-15
# 999                 incompetent customer service   United States   2018-07-13
#
#                aircraft_model     travel_type        seat_type  \
# 1                         NaN    Solo Leisure    Economy Class
# 2                         NaN    Solo Leisure    Economy Class
# 3                         NaN  Family Leisure    Economy Class
# 4                        A319        Business    Economy Class
# 5    Boeing 777-200 / 777-300        Business   Business Class
# ..                        ...             ...              ...
# 995                       NaN  Couple Leisure   Business Class
# 996                Boeing 777    Solo Leisure   Business Class
# 997          Boeing 777-300ER    Solo Leisure    Economy Class
# 998                       NaN  Couple Leisure  Premium Economy
# 999                       NaN  Couple Leisure    Economy Class
#
#                                      route  seat_comfort_rating  \
# 1                            Paris to Lyon                    5
# 2                                      NaN                    0
# 3            Tel Aviv to Toronto via Paris                    3
# 4                       Paris to Newcastle                    1
# 5          Conakry to Washington via Paris                    4
# ..                                     ...                  ...
# 995       Mumbai to Helsinki via Instanbul                    1
# 996                     Manila to Istanbul                    3
# 997        Tel Aviv to Manila via Istanbul                    3
# 998      Kayseri to Bucharest via Istanbul                    1
# 999  Los Angeles to Bucharest via Istanbul                    4
#
#      service_rating  food_rating  entertainment_rating  groundservice_rating  \
# 1                 5            5                     0                     5
# 2                 0            0                     0                     0
# 3                 1            2                     3                     1
# 4                 1            1                     0                     1
# 5                 4            4                     4                     2
# ..              ...          ...                   ...                   ...
# 995               2            2                     2                     1
# 996               1            1                     2                     2
# 997               1            2                     4                     3
# 998               1            1                     1                     1
# 999               4            5                     4                     1
#
#      wifi_rating  value_rating  recommended  year  month
# 1              0             5            1  2022      5
# 2              0             1            0  2022      4
# 3              4             1            0  2022      4
# 4              1             1            0  2022      4
# 5              4             3            1  2022      4
# ..           ...           ...          ...   ...    ...
# 995            0             1            0  2018      7
# 996            1             1            0  2018      7
# 997            0             1            0  2018      7
# 998            1             1            0  2018      7
# 999            4             1            0  2018      7
#
# [8309 rows x 19 columns]

# %%
#overall score for each travel type

Seat = df_airline_reviews.groupby('travel_type')['overall_score'].mean().reset_index().sort_values(by = 'overall_score', ascending = False)
import seaborn as sns
fig, ax = plt.subplots(figsize=(15,8))
sns.barplot(x="travel_type", y="overall_score", data=Seat, ax=ax)
# ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
for p in ax.patches:
    ax.annotate("%0.2f"%(p.get_height()), (p.get_x(), p.get_height() * 1.005)) 
plt.show()

# %%
#OVERALL SCORE GIVEN FOR EACH SEAT TYPE

Seat = df_airline_reviews.groupby('seat_type')['overall_score'].mean().reset_index().sort_values(by = 'overall_score', ascending = False)
import seaborn as sns
fig, ax = plt.subplots(figsize=(15,8))
sns.barplot(x="seat_type", y="overall_score", data=Seat, ax=ax)
# ax.set_xticklabels(ax.get_xticklabels(), rotation = 90)
for p in ax.patches:
    ax.annotate("%0.2f"%(p.get_height()), (p.get_x(), p.get_height() * 1.005)) 
plt.show()

# %%
#WORD ANALYTICS DONE FOR JAPAN AIRLINES FROM ITS REVIEWS

stopJapan = ['airline_name']
df_Japan = df_airline_reviews[df_airline_reviews['airline_name']=='Japan Airlines']
df_Japan.review_title = df_airline_reviews.review_title.apply(lambda x:" ".join(x for x in x.split() if x not in stopJapan))
wc = WordCloud(background_color="white", max_words=300, width=1000, height=600)
# generate word cloud
wc.generate(' '.join(df_Japan['review_title']))
plt.figure(figsize=(12, 6))
plt.imshow(wc,interpolation='bilinear')
plt.axis("off")
plt.show()
