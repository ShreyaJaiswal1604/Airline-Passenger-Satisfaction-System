# %%
import tweepy
import requests
import os
import json

CONSUMER_KEY = 'YIQlGxZrWJ5ns0V9R9sRteP23'
CONSUMER_SECRET = '4HKU5XpX6m4djwvphKwziKIjiZ7W4XgioHN7CH8tGBCN5ilWP8'
ACCESS_TOKEN = '1588210687918178304-whmYOsEugCmnp3SqqxcyaNCXkdVExR'
ACCESS_TOKEN_SECRET = 'ZMxZtnqhGbzlvTiX1Y8Qktqlb7QU3UDHfZnjQGnbloKC3'
BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAAG6diwEAAAAAJMsg5SlMVAlnDR1jyW38IkFdai4%3DL7O5v3e8C5MVGeNpcY6VyxAB6DZvhuFS9tUjt3YouHR6rz8Riw"


def create_url():
    tweet_fields = "tweet.fields=lang,author_id"
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    ids = "ids=1278747501642657792,1255542774432063488"
    # You can adjust ids to include a single Tweets.
    # Or you can add to up to 100 comma-separated IDs
    # url = "https://api.twitter.com/2/tweets?{}&{}".format(ids, tweet_fields)
    url = "https://api.twitter.com/2/tweets/search/recent?query=%23qatarairways (holiday OR review OR baggage OR business OR economy)&max_results=10".format(tweet_fields)
    return url


def bearer_oauth(r):
    r.headers["Authorization"] = f"Bearer {BEARER_TOKEN}"
    r.headers["User-Agent"] = "v2TweetLookupPython"
    return r


def connect_to_endpoint(url):
    response = requests.request("GET", url, auth=bearer_oauth)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()


def main():
    url = create_url()
    json_response = connect_to_endpoint(url)
    print(json.dumps(json_response, indent=2, sort_keys=True))


if __name__ == "__main__":
    main()
# Out:
# 200
# {
#   "data": [
#     {
#       "edit_history_tweet_ids": [
#         "1590130961999876102"
#       ],
#       "id": "1590130961999876102",
#       "text": "RT @qatarairways: #QatarAirways wins four awards at the 2022 Business Traveller Awards @BTUK :\n\u2022Best Long-Haul Airline\n\u2022Best Middle Eastern\u2026"
#     },
#     {
#       "edit_history_tweet_ids": [
#         "1589883025482973184"
#       ],
#       "id": "1589883025482973184",
#       "text": "The airbus #A380 of #QatarAirways has a bar on board! More photos and video here: https://t.co/d2EqOXVKDq https://t.co/WK5FnxlbOO"
#     },
#     {
#       "edit_history_tweet_ids": [
#         "1589729109953118209"
#       ],
#       "id": "1589729109953118209",
# ...

# %%
import mysql.connector

user = 'root'
password = 'localhost'
db = 'airline_passenger_satisfaction'
host='127.0.0.1'

#establishing the connection and creating cursor
try:
    conn = mysql.connector.connect(user = user, password = password, host = host, database = db)
    cursor = conn.cursor()
    print("Connection established to", db)
except:
    print("Error")

#Closing the connection
conn.close()
# Out:
# Connection established to airline_passenger_satisfaction
